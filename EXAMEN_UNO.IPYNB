# %%
""" :
FAVC: CONSUMICIÓN DE ALIMENTOS CALÓRICOS
FCVC: FRECUENCIA DE ALIMENTOS VEGETALES
NCP: COMIDAS PRINCIPALES POR DIA
CAEC: FRECUENCIA DE CONSUMO DE PICOTEO
CH2O: CONSUMO DE AGUA
FAF: FRECUENCIA DE ACTIVIDAD FISICA
TUE: TIEMPO GASTADO USANDO TECNOLOGIA
CALC: FRECUENCIA DE CONSUMO DE ALCOHOL
MTRANS: PRINCIPAL MEDIO DE TRANSPORTE
NOBEY: NIVEL DE OBESIDAD
SCC: MONITORIZAR CALORIAS (SI/NO)
FAMILY: HISTORIAL DE LA FAMILIA 
SMOKE: FUMA (SI/NO)
"""

# PASO 1, Importar las librerías necesarias
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# PASO 2, Cargar el CSV e inspeccionar el dataset
ob = pd.read_csv("ObesityDataSet_raw_and_data_sinthetic.csv")
print(ob.info())
print(ob.head())

# Inicializar LabelEncoder
label = LabelEncoder()
# Aplicar LabelEncoder a cada columna categórica
for col in ob:
    ob[col] = label.fit_transform(ob[col])

# Convertir columnas numéricas a tipo float
numeric_columns = ["Gender","Age","Height","Weight","family_history_with_overweight","FAVC","FCVC","NCP","CAEC","SMOKE","CH2O","SCC","FAF","TUE","CALC","MTRANS","NObeyesdad"]
ob[numeric_columns] = ob[numeric_columns].astype(float)



#No sé cómo hacer el proceso entero de ningún modelo, he estado hasta arriba de trabajo y temas familiares y no he repasado nada.
#Seguramente sea sencillo si repaso pero no he hecho nada y he faltado mucho.
#Lo volveré a intentar el miércoles a ver qué tal.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   int64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...
